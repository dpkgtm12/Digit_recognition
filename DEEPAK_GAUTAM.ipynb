# %%
 
from keras.datasets import mnist
data =mnist.load_data() you

# %%
((X_train,y_train),(X_test,y_test))=data

# %%
X_train=X_train.reshape((X_train.shape[0],28*28)).astype('float32')
X_test=X_test.reshape((X_test.shape[0],28*28)).astype('float32')

# %%
X_train=X_train/255
X_test=X_test/255

# %%
from keras.utils import np_utils
y_train=np_utils.to_categorical(y_train)
y_test=np_utils.to_categorical(y_test)
num_classes=y_test.shape[0]

# %%
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(32,input_dim=28*28, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
 model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=10,batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 7.1334 - accuracy: 0.5642
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.5678 - accuracy: 0.8519
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4202 - accuracy: 0.8918
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3552 - accuracy: 0.9064
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3211 - accuracy: 0.9140
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2914 - accuracy: 0.9214
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2906 - accuracy: 0.9226
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2664 - accuracy: 0.9272
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2593 - accuracy: 0.9315
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2479 - accuracy: 0.9348

# %%
score=model.evaluate(X_test,y_test)
print(score)
# Out:
# 313/313 [==============================] - 0s 849us/step - loss: 0.2848 - accuracy: 0.9302
# [0.28477469086647034, 0.9301999807357788]
